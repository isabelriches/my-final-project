# %%
import rand
Class card:
	Values = {2, 3, … 14}
Def  init (user, suit, value:
	user.suit = suit
	user.value = value
Def  repr (user):
	Return user.values [user.value] + “ of “ + user.suit
Def equals(user, card):
	Return user.suit == card.suit  and  user.value == card.value
