# %%
import random

class deck:
 suit = ["clubs", "spades", "hearts", "diamonds"]
 values = [x for x in range (2,15)]

def init(user):
 user.deck = []
 user.cards = user.initiate_cards()

def player_hand(user):
 return user.cards

def initiate_cards(user):
 cards = []
for suit in user.suits:
	for value in user.values:
		cards.append(card(suit, value))
		random.shuffle(cards)
		return cards

def grab_card(user):
 if user.cards:
	  return user.cards.pop()
# Out:
#   File "<ipython-input-1-c23fde05beae>", line 1
#     from card.ipynb import card.ipynb
#                                ^
# SyntaxError: invalid syntax
